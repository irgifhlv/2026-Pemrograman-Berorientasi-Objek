# %% [markdown]
# <a href="https://colab.research.google.com/github/irgifhlv/2026-Pemrograman-Berorientasi-Objek/blob/main/Jobsheet_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##PRAKTIKUM 1

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.__owner = owner
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"{amount} telah ditambahkan ke akun {self.__owner}.")
        else:
            print("Jumlah deposit harus lebih dari 0.")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"{amount} telah ditarik dari akun {self.__owner}.")
        else:
            print("Saldo tidak mencukupi.")

    def get_balance(self):
        return self.__balance


if __name__ == "__main__":
    alice_account = BankAccount("Alice", 1000)

    alice_account.deposit(500)
    alice_account.deposit(-100)

    alice_account.withdraw(300)
    alice_account.withdraw(2000)

    print(f"Saldo: {alice_account.get_balance()}")
# Out:
# 500 telah ditambahkan ke akun Alice.
# Jumlah deposit harus lebih dari 0.
# 300 telah ditarik dari akun Alice.
# Saldo tidak mencukupi.
# Saldo: 1200

# %% [markdown]
# ##PRAKTIKUM 2

# %%
class Employee:
    def __init__(self, name, salary):
        self.__name = name
        self.__salary = salary

    def update_salary(self, increase):
        if increase > 0:
            self.__salary += increase
            print(f"Gaji naik {increase}")
        else:
            print("Kenaikan harus > 0")

    def set_salary(self, new_salary):
        if new_salary >= 0:
            self.__salary = new_salary
        else:
            print("Gaji tidak boleh negatif")

    def get_salary(self):
        return self.__salary

    def get_employee_info(self):
        return f"{self.__name} - {self.__salary}"


if __name__ == "__main__":
    emp = Employee("John", 50000)
    print(emp.get_employee_info())

    emp.update_salary(5000)
    emp.set_salary(60000)

    print(emp.get_employee_info())
# Out:
# John - 50000
# Gaji naik 5000
# John - 60000

# %% [markdown]
# ##PRAKTIKUM 3

# %%
class SimpleExample:
    def __init__(self, name):
        self.name = name
        print(f"Objek {self.name} dibuat")

    def __del__(self):
        print(f"Objek {self.name} dihapus")


def main():
    obj = SimpleExample("Demo")
    del obj


if __name__ == "__main__":
    main()
# Out:
# Objek Demo dibuat
# Objek Demo dihapus

# %% [markdown]
# ##PRAKTIKUM 4

# %%
class FileLogger:
    def __init__(self, filename):
        self.filename = filename
        self.file = open(filename, "a")

    def write_log(self, message):
        self.file.write(message + "\n")
        self.file.flush()
        print("Log ditulis:", message)

    def __del__(self):
        if self.file:
            self.file.close()
            print("File ditutup")


if __name__ == "__main__":
    logger = FileLogger("log.txt")
    logger.write_log("Aplikasi dimulai")
    logger.write_log("Proses berjalan")
    del logger
# Out:
# Log ditulis: Aplikasi dimulai
# Log ditulis: Proses berjalan
# File ditutup

# %% [markdown]
# ##PRAKTIKUM 5

# %%
class Calculator:
    def __init__(self, initial_value=0):
        self.value = initial_value

    def add(self, number):
        self.value += number

    def subtract(self, number):
        self.value -= number

    def reset(self):
        self.value = 0

    def show_value(self):
        print(self.value)


if __name__ == "__main__":
    calc1 = Calculator(10)
    calc1.add(5)
    calc1.show_value()

    calc2 = Calculator()
    calc2.add(20)
    calc2.show_value()
# Out:
# 15
# 20

# %% [markdown]
# ## PRAKTIKUM 6

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        if value:
            self.__name = value

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, value):
        if value >= 0:
            self.__age = value


if __name__ == "__main__":
    p = Person("Alice", 30)
    print(p.name, p.age)

    p.name = "Bob"
    p.age = 35

    print(p.name, p.age)
# Out:
# Alice 30
# Bob 35

# %% [markdown]
# ## PENUGASAN

# %%
class Student:
    def __init__(self, name, score):
        self.__name = name
        self.__score = 0
        self.__grade = "E"
        self.score = score  # pakai setter

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        if value:
            self.__name = value
        else:
            print("Nama tidak boleh kosong")

    @property
    def score(self):
        return self.__score

    @score.setter
    def score(self, value):
        if 0 <= value <= 100:
            self.__score = value
            self.__update_grade()
        else:
            print("Nilai harus 0-100")

    def __update_grade(self):
        if self.__score >= 90:
            self.__grade = "A"
        elif self.__score >= 80:
            self.__grade = "B"
        elif self.__score >= 70:
            self.__grade = "C"
        elif self.__score >= 60:
            self.__grade = "D"
        else:
            self.__grade = "E"

    def show_info(self):
        print(f"Nama Mahasiswa: {self.__name}")
        print(f"Nilai: {self.__score}")
        print(f"Grade: {self.__grade}")

    def __del__(self):
        print(f"Data mahasiswa {self.__name} telah dihapus")


if __name__ == "__main__":
    s = Student("Irgi", 87)
    s.show_info()

    print("\nNilai diubah...\n")
    s.score = 93
    s.show_info()

    del s
# Out:
# Nama Mahasiswa: Irgi
# Nilai: 87
# Grade: B
#
# Nilai diubah...
#
# Nama Mahasiswa: Irgi
# Nilai: 93
# Grade: A
# Data mahasiswa Irgi telah dihapus
